# %%
import pandas as pd

# %%
feature_lookup = pd.DataFrame(columns=['Feature', 'Category', 'Availability', 'Description', 'High_vs_Low'])

# %%
geometry_features = [
    {'Feature': 'DwellingTypeDescr', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Type of dwelling (e.g., house, apartment)',
     'High_vs_Low': 'Varies by type; affects BER based on energy profile'},
    
    {'Feature': 'Year_of_Construction', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Year the building was constructed',
     'High_vs_Low': 'Older buildings usually have higher BER; newer buildings lower'},
    
    {'Feature': 'GroundFloorArea(sq m)', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Area of the ground floor in square meters',
     'High_vs_Low': 'Higher area may increase BER; lower area reduces BER'},
    
    {'Feature': 'GroundFloorArea', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Total ground floor area in m²',
     'High_vs_Low': 'Higher area may increase BER; lower area reduces BER'},
    
    {'Feature': 'GroundFloorHeight', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Height of the ground floor',
     'High_vs_Low': 'Higher floor height slightly increases energy demand'},
    
    {'Feature': 'FirstFloorArea', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Area of the first floor in square meters',
     'High_vs_Low': 'Higher area may increase BER; lower area reduces BER'},
    
    {'Feature': 'FirstFloorHeight', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Height of the first floor',
     'High_vs_Low': 'Higher floor height slightly increases energy demand'},
    
    {'Feature': 'SecondFloorArea', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Area of the second floor in square meters',
     'High_vs_Low': 'Higher area may increase BER; lower area reduces BER'},
    
    {'Feature': 'SecondFloorHeight', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Height of the second floor',
     'High_vs_Low': 'Higher floor height slightly increases energy demand'},
    
    {'Feature': 'WallArea', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Total area of walls',
     'High_vs_Low': 'Larger wall area may increase energy loss'},
    
    {'Feature': 'RoofArea', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Total roof area',
     'High_vs_Low': 'Larger roof area may increase energy loss'},
    
    {'Feature': 'FloorArea', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Total floor area of building',
     'High_vs_Low': 'Higher floor area increases energy demand'},
    
    {'Feature': 'WindowArea', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Total area of windows',
     'High_vs_Low': 'Larger window area may increase heat loss'},
    
    {'Feature': 'DoorArea', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Total area of doors',
     'High_vs_Low': 'Larger door area may increase heat loss'},
    
    {'Feature': 'RoomInRoofArea', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Area of rooms in roof space',
     'High_vs_Low': 'Higher area increases energy demand'},
    
    {'Feature': 'NoStoreys', 'Category': 'Geometry', 'Availability': 'Easy',
     'Description': 'Number of storeys in building',
     'High_vs_Low': 'More storeys generally increase BER'},
    
    {'Feature': 'LivingAreaPercent', 'Category': 'Geometry', 'Availability': 'Medium',
     'Description': 'Percentage of living area relative to total area',
     'High_vs_Low': 'Higher percentage may indicate more heated space'},
    
    {'Feature': 'LowEnergyLightingPercent', 'Category': 'Geometry', 'Availability': 'Medium',
     'Description': 'Percentage of low energy lighting',
     'High_vs_Low': 'Higher percentage reduces BER'},
    
    {'Feature': 'ThermalBridgingFactor', 'Category': 'Geometry', 'Availability': 'Hard',
     'Description': 'Impact of thermal bridging in the building envelope',
     'High_vs_Low': 'Higher factor increases energy loss'},
]

# %%
feature_lookup = pd.concat([feature_lookup, pd.DataFrame(geometry_features)], ignore_index=True)

# %%
feature_lookup
# Out:
#                      Feature  Category Availability  \
# 0          DwellingTypeDescr  Geometry         Easy
# 1       Year_of_Construction  Geometry         Easy
# 2      GroundFloorArea(sq m)  Geometry         Easy
# 3            GroundFloorArea  Geometry         Easy
# 4          GroundFloorHeight  Geometry         Easy
# 5             FirstFloorArea  Geometry         Easy
# 6           FirstFloorHeight  Geometry         Easy
# 7            SecondFloorArea  Geometry         Easy
# 8          SecondFloorHeight  Geometry         Easy
# 9                   WallArea  Geometry         Easy
# 10                  RoofArea  Geometry         Easy
# 11                 FloorArea  Geometry         Easy
# 12                WindowArea  Geometry         Easy
# 13                  DoorArea  Geometry         Easy
# 14            RoomInRoofArea  Geometry         Easy
# 15                 NoStoreys  Geometry         Easy
# 16         LivingAreaPercent  Geometry       Medium
# ...

# %%
envelope_features = [
    {'Feature': 'UValueWall', 'Category': 'Envelope', 'Availability': 'Medium',
     'Description': 'Thermal transmittance of external walls',
     'High_vs_Low': 'High U-value = poor insulation; low U-value = better insulation'},

    {'Feature': 'UValueRoof', 'Category': 'Envelope', 'Availability': 'Medium',
     'Description': 'Thermal transmittance of the roof',
     'High_vs_Low': 'High U-value increases heat loss; low U-value improves energy efficiency'},

    {'Feature': 'UValueFloor', 'Category': 'Envelope', 'Availability': 'Medium',
     'Description': 'Thermal transmittance of the floor',
     'High_vs_Low': 'High U-value increases heat loss; low U-value reduces BER'},

    {'Feature': 'UValueWindow', 'Category': 'Envelope', 'Availability': 'Medium',
     'Description': 'Thermal transmittance of windows',
     'High_vs_Low': 'High U-value = more heat loss; low U-value = better insulation'},

    {'Feature': 'UvalueDoor', 'Category': 'Envelope', 'Availability': 'Medium',
     'Description': 'Thermal transmittance of doors',
     'High_vs_Low': 'High U-value increases heat loss; low U-value improves energy efficiency'},

    {'Feature': 'GroundFloorUValue', 'Category': 'Envelope', 'Availability': 'Medium',
     'Description': 'U-value specific to ground floor',
     'High_vs_Low': 'Higher U-value increases heat loss'},

    {'Feature': 'FirstWallArea', 'Category': 'Envelope', 'Availability': 'Easy',
     'Description': 'Area of the first wall',
     'High_vs_Low': 'Larger area may increase heat loss'},

    {'Feature': 'FirstWallUValue', 'Category': 'Envelope', 'Availability': 'Medium',
     'Description': 'U-value of first wall',
     'High_vs_Low': 'High = poor insulation; low = better insulation'},

    {'Feature': 'FirstWallAgeBandId', 'Category': 'Envelope', 'Availability': 'Medium',
     'Description': 'Age category of the first wall',
     'High_vs_Low': 'Older walls may have higher BER'},

    {'Feature': 'FirstWallTypeId', 'Category': 'Envelope', 'Availability': 'Medium',
     'Description': 'Type of first wall (e.g., cavity, solid)',
     'High_vs_Low': 'Type affects insulation and BER'},

    {'Feature': 'FirstWallType_Description', 'Category': 'Envelope', 'Availability': 'Medium',
     'Description': 'Textual description of wall type',
     'High_vs_Low': 'Type affects insulation and energy loss'},

    {'Feature': 'PredominantRoofType', 'Category': 'Envelope', 'Availability': 'Medium',
     'Description': 'Main roof type (e.g., pitched, flat)',
     'High_vs_Low': 'Type affects heat loss'},

    {'Feature': 'PredominantRoofTypeArea', 'Category': 'Envelope', 'Availability': 'Easy',
     'Description': 'Area of predominant roof type',
     'High_vs_Low': 'Larger area may increase energy loss'},

    {'Feature': 'InsulationType', 'Category': 'Envelope', 'Availability': 'Medium',
     'Description': 'Type of insulation installed',
     'High_vs_Low': 'Better insulation reduces BER'},

    {'Feature': 'InsulationThickness', 'Category': 'Envelope', 'Availability': 'Medium',
     'Description': 'Thickness of insulation layer',
     'High_vs_Low': 'Thicker insulation reduces energy loss'},

    {'Feature': 'ThermalMassCategory', 'Category': 'Envelope', 'Availability': 'Medium',
     'Description': 'Thermal mass of the building envelope',
     'High_vs_Low': 'Higher thermal mass can stabilize indoor temperatures'}
]

# %%
feature_lookup = pd.concat([feature_lookup, pd.DataFrame(envelope_features)], ignore_index=True)

# %%
feature_lookup
# Out:
#                       Feature  Category Availability  \
# 0           DwellingTypeDescr  Geometry         Easy
# 1        Year_of_Construction  Geometry         Easy
# 2       GroundFloorArea(sq m)  Geometry         Easy
# 3             GroundFloorArea  Geometry         Easy
# 4           GroundFloorHeight  Geometry         Easy
# 5              FirstFloorArea  Geometry         Easy
# 6            FirstFloorHeight  Geometry         Easy
# 7             SecondFloorArea  Geometry         Easy
# 8           SecondFloorHeight  Geometry         Easy
# 9                    WallArea  Geometry         Easy
# 10                   RoofArea  Geometry         Easy
# 11                  FloorArea  Geometry         Easy
# 12                 WindowArea  Geometry         Easy
# 13                   DoorArea  Geometry         Easy
# 14             RoomInRoofArea  Geometry         Easy
# 15                  NoStoreys  Geometry         Easy
# 16          LivingAreaPercent  Geometry       Medium
# ...

# %%
heating_features = [
    # --- Main Heating Fuel ---
    {'Feature': 'MainSpaceHeatingFuel', 'Category': 'Heating Fuel', 'Availability': 'Easy',
     'Description': 'Primary fuel used for space heating',
     'High_vs_Low': 'Fuel type impacts energy efficiency; renewable fuels lower BER'},
    
    {'Feature': 'MainWaterHeatingFuel', 'Category': 'Heating Fuel', 'Availability': 'Easy',
     'Description': 'Primary fuel used for water heating',
     'High_vs_Low': 'Fuel type impacts energy efficiency'},

    # --- Heating System Efficiency ---
    {'Feature': 'HSMainSystemEfficiency', 'Category': 'Heating Efficiency', 'Availability': 'Medium',
     'Description': 'Efficiency of the main heating system',
     'High_vs_Low': 'Higher efficiency reduces BER'},
    
    {'Feature': 'HSEffAdjFactor', 'Category': 'Heating Efficiency', 'Availability': 'Medium',
     'Description': 'Adjustment factor for heating system efficiency',
     'High_vs_Low': 'Higher factor reduces BER'},
    
    {'Feature': 'HSSupplHeatFraction', 'Category': 'Heating Efficiency', 'Availability': 'Medium',
     'Description': 'Fraction of heating provided by supplementary system',
     'High_vs_Low': 'Higher fraction may increase BER if less efficient'},
    
    {'Feature': 'HSSupplSystemEff', 'Category': 'Heating Efficiency', 'Availability': 'Medium',
     'Description': 'Efficiency of supplementary heating system',
     'High_vs_Low': 'Higher efficiency reduces BER'},

    # --- Water Heating ---
    {'Feature': 'WHMainSystemEff', 'Category': 'Hot Water', 'Availability': 'Medium',
     'Description': 'Efficiency of main water heating system',
     'High_vs_Low': 'Higher efficiency reduces BER'},
    
    {'Feature': 'WHEffAdjFactor', 'Category': 'Hot Water', 'Availability': 'Medium',
     'Description': 'Adjustment factor for water heating efficiency',
     'High_vs_Low': 'Higher factor reduces BER'},
    
    {'Feature': 'SupplSHFuel', 'Category': 'Heating Fuel', 'Availability': 'Medium',
     'Description': 'Fuel type of supplementary space heating',
     'High_vs_Low': 'Efficient or renewable fuel reduces BER'},
    
    {'Feature': 'SupplWHFuel', 'Category': 'Heating Fuel', 'Availability': 'Medium',
     'Description': 'Fuel type of supplementary water heating',
     'High_vs_Low': 'Efficient or renewable fuel reduces BER'},
    
    {'Feature': 'SHRenewableResources', 'Category': 'Heating Fuel', 'Availability': 'Medium',
     'Description': 'Use of renewable resources for space heating',
     'High_vs_Low': 'Higher renewable fraction reduces BER'},
    
    {'Feature': 'WHRenewableResources', 'Category': 'Heating Fuel', 'Availability': 'Medium',
     'Description': 'Use of renewable resources for water heating',
     'High_vs_Low': 'Higher renewable fraction reduces BER'},

    # --- Ventilation & Chimneys ---
    {'Feature': 'NoOfChimneys', 'Category': 'Ventilation', 'Availability': 'Easy',
     'Description': 'Number of chimneys in the building',
     'High_vs_Low': 'More chimneys may increase heat loss'},
    
    {'Feature': 'NoOfOpenFlues', 'Category': 'Ventilation', 'Availability': 'Easy',
     'Description': 'Number of open flues',
     'High_vs_Low': 'More open flues increase energy loss'},
    
    {'Feature': 'NoOfFansAndVents', 'Category': 'Ventilation', 'Availability': 'Easy',
     'Description': 'Number of fans and vents',
     'High_vs_Low': 'Higher number may increase energy use'},
    
    {'Feature': 'DraftLobby', 'Category': 'Ventilation', 'Availability': 'Medium',
     'Description': 'Presence of a draft lobby',
     'High_vs_Low': 'Reduces heat loss if present'},
    
    {'Feature': 'VentilationMethod', 'Category': 'Ventilation', 'Availability': 'Medium',
     'Description': 'Type of ventilation system',
     'High_vs_Low': 'Efficiency affects BER'},
    
    {'Feature': 'FanPowerManuDeclaredValue', 'Category': 'Ventilation', 'Availability': 'Medium',
     'Description': 'Declared power of fans',
     'High_vs_Low': 'Higher power increases energy demand'},
    
    {'Feature': 'HeatExchangerEff', 'Category': 'Ventilation', 'Availability': 'Medium',
     'Description': 'Efficiency of heat recovery in ventilation',
     'High_vs_Low': 'Higher efficiency reduces BER'},

    # --- Misc / Building Structure ---
    {'Feature': 'StructureType', 'Category': 'Building Structure', 'Availability': 'Easy',
     'Description': 'Type of building structure (e.g., masonry, timber)',
     'High_vs_Low': 'Structure type affects thermal performance'},
    
    {'Feature': 'SuspendedWoodenFloor', 'Category': 'Building Structure', 'Availability': 'Medium',
     'Description': 'Whether the building has suspended wooden floor',
     'High_vs_Low': 'May increase heat loss if present'},
    
    {'Feature': 'PercentageDraughtStripped', 'Category': 'Building Structure', 'Availability': 'Medium',
     'Description': 'Percentage of doors/windows draught-proofed',
     'High_vs_Low': 'Higher percentage reduces BER'},
    
    {'Feature': 'NoOfSidesSheltered', 'Category': 'Building Structure', 'Availability': 'Medium',
     'Description': 'Number of sides sheltered from wind',
     'High_vs_Low': 'More sheltered sides reduce energy loss'},
    
    {'Feature': 'PermeabilityTest', 'Category': 'Ventilation', 'Availability': 'Medium',
     'Description': 'Whether air permeability test conducted',
     'High_vs_Low': 'Lower permeability reduces BER'},
    
    {'Feature': 'PermeabilityTestResult', 'Category': 'Ventilation', 'Availability': 'Medium',
     'Description': 'Result of air permeability test',
     'High_vs_Low': 'Lower result reduces energy loss'},
    
    {'Feature': 'TempAdjustment', 'Category': 'Ventilation', 'Availability': 'Medium',
     'Description': 'Temperature adjustment factor',
     'High_vs_Low': 'Higher values increase calculated BER'},

    # --- Heating Controls & Pumps ---
    {'Feature': 'HeatSystemControlCat', 'Category': 'Heating Control', 'Availability': 'Medium',
     'Description': 'Heating system control category',
     'High_vs_Low': 'Better control reduces BER'},
    
    {'Feature': 'HeatSystemResponseCat', 'Category': 'Heating Control', 'Availability': 'Medium',
     'Description': 'System response category',
     'High_vs_Low': 'Faster response improves efficiency'},
    
    {'Feature': 'NoCentralHeatingPumps', 'Category': 'Pumps & Losses', 'Availability': 'Medium',
     'Description': 'Number of central heating pumps',
     'High_vs_Low': 'More pumps may slightly increase BER'},
    
    {'Feature': 'CHBoilerThermostatControlled', 'Category': 'Pumps & Losses', 'Availability': 'Medium',
     'Description': 'Whether central heating boiler is thermostat-controlled',
     'High_vs_Low': 'Yes = reduces energy waste'},
    
    {'Feature': 'NoOilBoilerHeatingPumps', 'Category': 'Pumps & Losses', 'Availability': 'Medium',
     'Description': 'Number of oil boiler pumps',
     'High_vs_Low': 'More pumps may increase energy use'},
    
    {'Feature': 'OBBoilerThermostatControlled', 'Category': 'Pumps & Losses', 'Availability': 'Medium',
     'Description': 'Oil boiler thermostat control',
     'High_vs_Low': 'Yes = reduces energy waste'},
    
    {'Feature': 'OBPumpInsideDwelling', 'Category': 'Pumps & Losses', 'Availability': 'Medium',
     'Description': 'Oil boiler pump location',
     'High_vs_Low': 'Inside dwelling reduces heat loss'},
    
    {'Feature': 'NoGasBoilerHeatingPumps', 'Category': 'Pumps & Losses', 'Availability': 'Medium',
     'Description': 'Number of gas boiler pumps',
     'High_vs_Low': 'More pumps may increase energy use'},
    
    {'Feature': 'UndergroundHeating', 'Category': 'Pumps & Losses', 'Availability': 'Medium',
     'Description': 'Presence of underground heating system',
     'High_vs_Low': 'May improve or reduce BER depending on efficiency'},

    # --- Losses & Storage ---
    {'Feature': 'DistributionLosses', 'Category': 'Losses', 'Availability': 'Medium',
     'Description': 'Heat distribution losses',
     'High_vs_Low': 'Higher losses increase BER'},
    
    {'Feature': 'StorageLosses', 'Category': 'Losses', 'Availability': 'Medium',
     'Description': 'Heat storage losses',
     'High_vs_Low': 'Higher losses increase BER'},
    
    {'Feature': 'ManuLossFactorAvail', 'Category': 'Losses', 'Availability': 'Medium',
     'Description': 'Loss factor provided by manufacturer',
     'High_vs_Low': 'Higher factor may increase BER'},

    # --- Solar & Hot Water Systems ---
    {'Feature': 'SolarHotWaterHeating', 'Category': 'Hot Water', 'Availability': 'Medium',
     'Description': 'Presence of solar hot water system',
     'High_vs_Low': 'Reduces BER if present'},
    
    {'Feature': 'ElecImmersionInSummer', 'Category': 'Hot Water', 'Availability': 'Medium',
     'Description': 'Use of electric immersion heater in summer',
     'High_vs_Low': 'Increases energy use if present'},
    
    {'Feature': 'CombiBoiler', 'Category': 'Hot Water', 'Availability': 'Medium',
     'Description': 'Presence of combi boiler system',
     'High_vs_Low': 'Efficient systems reduce BER'},
    
    {'Feature': 'KeepHotFacility', 'Category': 'Hot Water', 'Availability': 'Medium',
     'Description': 'Keep-hot facility in cylinder',
     'High_vs_Low': 'Maintains temperature; may increase losses'},
    
    {'Feature': 'WaterStorageVolume', 'Category': 'Hot Water', 'Availability': 'Medium',
     'Description': 'Volume of water stored',
     'High_vs_Low': 'Larger volume may increase storage losses'},
    
    {'Feature': 'DeclaredLossFactor', 'Category': 'Hot Water', 'Availability': 'Medium',
     'Description': 'Declared loss factor for hot water system',
     'High_vs_Low': 'Higher factor increases energy loss'},
    
    {'Feature': 'TempFactorUnadj', 'Category': 'Hot Water', 'Availability': 'Medium',
     'Description': 'Temperature factor unadjusted',
     'High_vs_Low': 'Higher factor increases BER'},
    
    {'Feature': 'TempFactorMultiplier', 'Category': 'Hot Water', 'Availability': 'Medium',
     'Description': 'Multiplier for temperature factor',
     'High_vs_Low': 'Higher value increases energy loss'},
    
    {'Feature': 'PrimaryCircuitLoss', 'Category': 'Hot Water', 'Availability': 'Medium',
     'Description': 'Primary circuit heat loss',
     'High_vs_Low': 'Higher loss increases BER'},
    
    {'Feature': 'CylinderStat', 'Category': 'Hot Water', 'Availability': 'Medium',
     'Description': 'Cylinder thermostat status',
     'High_vs_Low': 'Better control reduces BER'},
    
    {'Feature': 'CombinedCylinder', 'Category': 'Hot Water', 'Availability': 'Medium',
     'Description': 'Combined cylinder type',
     'High_vs_Low': 'Efficient type reduces energy loss'},
]

# %%
feature_lookup = pd.concat([feature_lookup, pd.DataFrame(heating_features)], ignore_index=True)

# %%
feature_lookup
# Out:
#                   Feature   Category Availability  \
# 0       DwellingTypeDescr   Geometry         Easy
# 1    Year_of_Construction   Geometry         Easy
# 2   GroundFloorArea(sq m)   Geometry         Easy
# 3         GroundFloorArea   Geometry         Easy
# 4       GroundFloorHeight   Geometry         Easy
# ..                    ...        ...          ...
# 79        TempFactorUnadj  Hot Water       Medium
# 80   TempFactorMultiplier  Hot Water       Medium
# 81     PrimaryCircuitLoss  Hot Water       Medium
# 82           CylinderStat  Hot Water       Medium
# 83       CombinedCylinder  Hot Water       Medium
#
#                                   Description  \
# 0   Type of dwelling (e.g., house, apartment)
# 1           Year the building was constructed
# 2   Area of the ground floor in square meters
# 3               Total ground floor area in m²
# 4                  Height of the ground floor
# ..                                        ...
# ...

# %%
energy_features = [
    # --- Delivered Energy: Lighting ---
    {'Feature': 'DeliveredLightingEnergy', 'Category': 'Lighting', 'Availability': 'Moderate',
     'Description': 'Energy delivered for lighting',
     'High_vs_Low': 'Higher values indicate higher energy use'},
    
    {'Feature': 'PrimaryEnergyLighting', 'Category': 'Lighting', 'Availability': 'Moderate',
     'Description': 'Primary energy for lighting',
     'High_vs_Low': 'Higher values increase BER'},
    
    {'Feature': 'CO2Lighting', 'Category': 'Lighting', 'Availability': 'Moderate',
     'Description': 'CO2 emissions from lighting',
     'High_vs_Low': 'Higher emissions indicate inefficient lighting'},

    # --- Pumps & Fans ---
    {'Feature': 'DeliveredEnergyPumpsFans', 'Category': 'Pumps & Fans', 'Availability': 'Moderate',
     'Description': 'Delivered energy for pumps and fans',
     'High_vs_Low': 'Higher values increase BER'},
    
    {'Feature': 'PrimaryEnergyPumpsFans', 'Category': 'Pumps & Fans', 'Availability': 'Moderate',
     'Description': 'Primary energy for pumps and fans',
     'High_vs_Low': 'Higher values increase BER'},
    
    {'Feature': 'CO2PumpsFans', 'Category': 'Pumps & Fans', 'Availability': 'Moderate',
     'Description': 'CO2 emissions from pumps and fans',
     'High_vs_Low': 'Higher emissions indicate inefficiency'},

    # --- Water Heating ---
    {'Feature': 'DeliveredEnergyMainWater', 'Category': 'Water Heating', 'Availability': 'Moderate',
     'Description': 'Energy delivered for main water heating',
     'High_vs_Low': 'Higher values increase BER'},
    
    {'Feature': 'PrimaryEnergyMainWater', 'Category': 'Water Heating', 'Availability': 'Moderate',
     'Description': 'Primary energy for main water heating',
     'High_vs_Low': 'Higher values increase BER'},
    
    {'Feature': 'CO2MainWater', 'Category': 'Water Heating', 'Availability': 'Moderate',
     'Description': 'CO2 emissions from water heating',
     'High_vs_Low': 'Higher values indicate inefficiency'},
    
    {'Feature': 'PrimaryEnergySupplementaryWater', 'Category': 'Water Heating', 'Availability': 'Moderate',
     'Description': 'Primary energy for supplementary water heating',
     'High_vs_Low': 'Higher values increase BER'},

    # --- Space Heating ---
    {'Feature': 'DeliveredEnergyMainSpace', 'Category': 'Space Heating', 'Availability': 'Moderate',
     'Description': 'Delivered energy for main space heating',
     'High_vs_Low': 'Higher values increase BER'},
    
    {'Feature': 'PrimaryEnergyMainSpace', 'Category': 'Space Heating', 'Availability': 'Moderate',
     'Description': 'Primary energy for main space heating',
     'High_vs_Low': 'Higher values increase BER'},
    
    {'Feature': 'DeliveredEnergySecondarySpace', 'Category': 'Space Heating', 'Availability': 'Moderate',
     'Description': 'Delivered energy for secondary space heating',
     'High_vs_Low': 'Higher values increase BER'},
    
    {'Feature': 'PrimaryEnergySecondarySpace', 'Category': 'Space Heating', 'Availability': 'Moderate',
     'Description': 'Primary energy for secondary space heating',
     'High_vs_Low': 'Higher values increase BER'},
    
    {'Feature': 'CO2MainSpace', 'Category': 'Space Heating', 'Availability': 'Moderate',
     'Description': 'CO2 emissions from space heating',
     'High_vs_Low': 'Higher values indicate inefficiency'},
    
    {'Feature': 'CO2SecondarySpace', 'Category': 'Space Heating', 'Availability': 'Moderate',
     'Description': 'CO2 emissions from secondary space heating',
     'High_vs_Low': 'Higher values indicate inefficiency'},

    # --- Scheme / Upgrade ---
    {'Feature': 'HESSchemeUpgrade', 'Category': 'Scheme', 'Availability': 'Moderate',
     'Description': 'Whether the building has undergone HES scheme upgrade',
     'High_vs_Low': 'Upgrade generally lowers BER'},

    # --- Energy Type Details ---
    {'Feature': 'FirstEnergyTypeId', 'Category': 'Energy Type', 'Availability': 'Easy',
     'Description': 'ID of first energy type used',
     'High_vs_Low': 'Type affects energy efficiency'},
    
    {'Feature': 'FirstEnergyType_Description', 'Category': 'Energy Type', 'Availability': 'Easy',
     'Description': 'Description of first energy type',
     'High_vs_Low': 'Type affects energy efficiency'},
    
    {'Feature': 'FirstEnerProdDelivered', 'Category': 'Energy Type', 'Availability': 'Moderate',
     'Description': 'Delivered energy of first energy product',
     'High_vs_Low': 'Higher values increase BER'},
    
    {'Feature': 'FirstPartLTotalContribution', 'Category': 'Energy Type', 'Availability': 'Moderate',
     'Description': 'Contribution of first product to total energy',
     'High_vs_Low': 'Higher contribution increases BER'},
    
    {'Feature': 'FirstEnerProdConvFactor', 'Category': 'Energy Type', 'Availability': 'Moderate',
     'Description': 'Conversion factor for first energy product',
     'High_vs_Low': 'Higher factor increases calculated BER'},
    
    {'Feature': 'FirstEnerProdCO2EmissionFactor', 'Category': 'Energy Type', 'Availability': 'Moderate',
     'Description': 'CO2 emission factor for first energy product',
     'High_vs_Low': 'Higher factor increases emissions'},
    
    {'Feature': 'SecondEnergyType_Description', 'Category': 'Energy Type', 'Availability': 'Easy',
     'Description': 'Description of second energy type',
     'High_vs_Low': 'Type affects overall BER'},
]

# %%
feature_lookup = pd.concat([feature_lookup, pd.DataFrame(energy_features)], ignore_index=True)

# %%
feature_lookup
# Out:
#                             Feature     Category Availability  \
# 0                 DwellingTypeDescr     Geometry         Easy
# 1              Year_of_Construction     Geometry         Easy
# 2             GroundFloorArea(sq m)     Geometry         Easy
# 3                   GroundFloorArea     Geometry         Easy
# 4                 GroundFloorHeight     Geometry         Easy
# ..                              ...          ...          ...
# 103          FirstEnerProdDelivered  Energy Type     Moderate
# 104     FirstPartLTotalContribution  Energy Type     Moderate
# 105         FirstEnerProdConvFactor  Energy Type     Moderate
# 106  FirstEnerProdCO2EmissionFactor  Energy Type     Moderate
# 107    SecondEnergyType_Description  Energy Type         Easy
#
#                                        Description  \
# 0        Type of dwelling (e.g., house, apartment)
# 1                Year the building was constructed
# 2        Area of the ground floor in square meters
# ...

# %%
error_features = [
    {
        'Feature': 'prob_smarea_error_0corr',
        'Category': 'Error / Probability',
        'Availability': 'Easy',
        'Description': 'Probability of small area error being 0%',
        'High_vs_Low': 'Higher probability may indicate more accurate measurement'
    },
    {
        'Feature': 'prob_smarea_error_100corr',
        'Category': 'Error / Probability',
        'Availability': 'Easy',
        'Description': 'Probability of small area error being 100%',
        'High_vs_Low': 'Higher probability indicates higher potential error'
    }
]

feature_lookup = pd.concat([feature_lookup, pd.DataFrame(error_features)], ignore_index=True)
feature_lookup
# Out:
#                             Feature             Category Availability  \
# 0                 DwellingTypeDescr             Geometry         Easy
# 1              Year_of_Construction             Geometry         Easy
# 2             GroundFloorArea(sq m)             Geometry         Easy
# 3                   GroundFloorArea             Geometry         Easy
# 4                 GroundFloorHeight             Geometry         Easy
# ..                              ...                  ...          ...
# 105         FirstEnerProdConvFactor          Energy Type     Moderate
# 106  FirstEnerProdCO2EmissionFactor          Energy Type     Moderate
# 107    SecondEnergyType_Description          Energy Type         Easy
# 108         prob_smarea_error_0corr  Error / Probability         Easy
# 109       prob_smarea_error_100corr  Error / Probability         Easy
#
#                                       Description  \
# 0       Type of dwelling (e.g., house, apartment)
# ...

# %%
id_features = [
    {
        'Feature': 'CountyName',
        'Category': 'Identification / Metadata',
        'Availability': 'Easy',
        'Description': 'County where the building is located',
        'High_vs_Low': 'Contextual, does not affect BER directly'
    },
    {
        'Feature': 'DateOfAssessment',
        'Category': 'Identification / Metadata',
        'Availability': 'Easy',
        'Description': 'Date when BER assessment was performed',
        'High_vs_Low': 'Useful for temporal trends, not direct impact'
    },
    {
        'Feature': 'SA_Code',
        'Category': 'Identification / Metadata',
        'Availability': 'Easy',
        'Description': 'Unique code for the assessed dwelling',
        'High_vs_Low': 'Identifier, not predictive'
    },
    {
        'Feature': 'PurposeOfRating',
        'Category': 'Identification / Metadata',
        'Availability': 'Easy',
        'Description': 'Reason for the BER assessment (e.g., sale, rental)',
        'High_vs_Low': 'Contextual only'
    },
    {
        'Feature': 'TypeofRating',
        'Category': 'Identification / Metadata',
        'Availability': 'Easy',
        'Description': 'Type of BER rating (e.g., Dwellings, New Build)',
        'High_vs_Low': 'Contextual, not directly predictive'
    },
    {
        'Feature': 'FirstWallDescription',
        'Category': 'Identification / Metadata',
        'Availability': 'Moderate',
        'Description': 'Text description of first wall type',
        'High_vs_Low': 'Contextual, may help explain wall performance'
    }
]

feature_lookup = pd.concat([feature_lookup, pd.DataFrame(id_features)], ignore_index=True)
feature_lookup
# Out:
#                    Feature                   Category Availability  \
# 0        DwellingTypeDescr                   Geometry         Easy
# 1     Year_of_Construction                   Geometry         Easy
# 2    GroundFloorArea(sq m)                   Geometry         Easy
# 3          GroundFloorArea                   Geometry         Easy
# 4        GroundFloorHeight                   Geometry         Easy
# ..                     ...                        ...          ...
# 111       DateOfAssessment  Identification / Metadata         Easy
# 112                SA_Code  Identification / Metadata         Easy
# 113        PurposeOfRating  Identification / Metadata         Easy
# 114           TypeofRating  Identification / Metadata         Easy
# 115   FirstWallDescription  Identification / Metadata     Moderate
#
#                                            Description  \
# 0            Type of dwelling (e.g., house, apartment)
# ...

# %%
leakage_features = [
    {
        'Feature': 'CO2Rating',
        'Category': 'Leakage / Target',
        'Availability': 'Easy',
        'Description': 'CO2 emission rating derived from BER',
        'High_vs_Low': 'Higher indicates worse energy performance'
    },
    {
        'Feature': 'EnergyRating',
        'Category': 'Leakage / Target',
        'Availability': 'Easy',
        'Description': 'Energy rating derived from BER',
        'High_vs_Low': 'Higher indicates worse energy performance'
    },
    {
        'Feature': 'CPC',
        'Category': 'Leakage / Target',
        'Availability': 'Easy',
        'Description': 'Building energy performance certificate rating (categorical)',
        'High_vs_Low': 'Dependent on BER'
    },
    {
        'Feature': 'EPC',
        'Category': 'Leakage / Target',
        'Availability': 'Easy',
        'Description': 'Energy performance certificate label',
        'High_vs_Low': 'Dependent on BER'
    },
    {
        'Feature': 'BER_bin',
        'Category': 'Leakage / Target',
        'Availability': 'Easy',
        'Description': 'Binned version of BER (categorical)',
        'High_vs_Low': 'Dependent on BER'
    }
]

feature_lookup = pd.concat([feature_lookup, pd.DataFrame(leakage_features)], ignore_index=True)
feature_lookup.tail(10)
# Out:
#                   Feature                   Category Availability  \
# 111      DateOfAssessment  Identification / Metadata         Easy
# 112               SA_Code  Identification / Metadata         Easy
# 113       PurposeOfRating  Identification / Metadata         Easy
# 114          TypeofRating  Identification / Metadata         Easy
# 115  FirstWallDescription  Identification / Metadata     Moderate
# 116             CO2Rating           Leakage / Target         Easy
# 117          EnergyRating           Leakage / Target         Easy
# 118                   CPC           Leakage / Target         Easy
# 119                   EPC           Leakage / Target         Easy
# 120               BER_bin           Leakage / Target         Easy
#
#                                            Description  \
# 111             Date when BER assessment was performed
# 112              Unique code for the assessed dwelling
# 113  Reason for the BER assessment (e.g., sale, ren...
# ...

# %%
duplicates = feature_lookup[feature_lookup.duplicated(subset=['Feature'], keep=False)]

if not duplicates.empty:
    print("Duplicate feature names found:")
    display(duplicates)
else:
    print("No duplicate feature names in feature_lookup")
# Out:
# No duplicate feature names in feature_lookup

# %%
# Load cleaned dataset
file_path = r"..\dataset\BERPublicsearch_Cleaned.csv"
df = pd.read_csv(file_path)
print("Loaded cleaned dataset")
# Out:
# Loaded cleaned dataset

# %%
all_cols = df.columns.tolist()
missing_in_lookup = [col for col in all_cols if col not in feature_lookup['Feature'].tolist()]

print(f"Number of columns missing in feature_lookup: {len(missing_in_lookup)}")
print("Missing columns:")
for col in missing_in_lookup:
    print(f"- {col}")
# Out:
# Number of columns missing in feature_lookup: 3
# Missing columns:
# - BerRating
# - TGDLEdition
# - MPCDERValue

# %%
missing_features = [
    {
        'Feature': 'TGDLEdition',
        'Category': 'Heating / Mechanical System',
        'Availability': 'Easy',  # assessor can provide
        'Description': 'Technical Guidance Document Edition used for heating calculations',
        'High_vs_Low': 'Higher edition may indicate updated efficiency standards'
    },
    {
        'Feature': 'MPCDERValue',
        'Category': 'Heating / Mechanical System',
        'Availability': 'Moderate',  # may require calculation or lookup
        'Description': 'Maximum Primary Circuit Design Energy Requirement',
        'High_vs_Low': 'Higher value indicates higher energy demand for space heating'
    }
]
# Append to feature_lookup
feature_lookup = pd.concat([feature_lookup, pd.DataFrame(missing_features)], ignore_index=True)

# %%
feature_lookup
# Out:
#                    Feature                     Category Availability  \
# 0        DwellingTypeDescr                     Geometry         Easy
# 1     Year_of_Construction                     Geometry         Easy
# 2    GroundFloorArea(sq m)                     Geometry         Easy
# 3          GroundFloorArea                     Geometry         Easy
# 4        GroundFloorHeight                     Geometry         Easy
# ..                     ...                          ...          ...
# 118                    CPC             Leakage / Target         Easy
# 119                    EPC             Leakage / Target         Easy
# 120                BER_bin             Leakage / Target         Easy
# 121            TGDLEdition  Heating / Mechanical System         Easy
# 122            MPCDERValue  Heating / Mechanical System     Moderate
#
#                                            Description  \
# 0            Type of dwelling (e.g., house, apartment)
# ...

# %%
feature_lookup.to_csv('..\dataset\BER_feature_lookup.csv', index=False)
